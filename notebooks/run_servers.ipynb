# %% [markdown]
# ## Run TTS Server

# %% [markdown]
# ### Tagged TTS server

# %%
# %cd /mnt/d/workspace/text_to_speech/viterbox-tts
# !python openai_server/tagged_tts_server.py --no-normalize

# %% [markdown]
# ### TTS Server (no tagged)

# %%
# %cd /mnt/d/workspace/text_to_speech/viterbox-tts
# !python openai_server/tts_server.py --no-normalize
# Out:
# /mnt/d/workspace/text_to_speech/viterbox-tts
# ...
# Fetching 5 files: 100%|████████████████████████| 5/5 [00:00<00:00, 70611.18it/s]
# 2026-02-04 16:47:32,256 - __main__ - INFO - Viterbox model loaded successfully
# INFO:__main__:Viterbox model loaded successfully
# 2026-02-04 16:47:32,257 - __main__ - INFO - Text normalization: disabled
# INFO:__main__:Text normalization: disabled
# Server started on port 8088
# 2026-02-04 16:47:46,146 - __main__ - INFO - Using speaker: storyteller_1
# INFO:__main__:Using speaker: storyteller_1
# 2026-02-04 16:47:46,146 - __main__ - INFO - Start processing text: Tu sĩ trung niên sững sờ. Cái ... [length: 71]
# INFO:__main__:Start processing text: Tu sĩ trung niên sững sờ. Cái ... [length: 71]
# 2026-02-04 16:47:46,146 - __main__ - INFO - Speaker ID: storyteller_1
# INFO:__main__:Speaker ID: storyteller_1
# max value is  tensor(1.0001, device='cuda:0')
#   [1/2] Tu sĩ trung niên sững sờ....
# ...
